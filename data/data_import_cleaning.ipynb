# %%
import numpy as np
import pandas as pd
import openpyxl

# %% [markdown]
# ## Import Assignments

# %%
assignments_fall = pd.read_excel('current_learning_objectives_raw_data.xlsx', sheet_name='fall2021_assignments')
assignments_fall['term_id'] = 'fall2021'
assignments_fall
# Out:
#             mnemonic                                        course_name  \
# 0   ds_tech_bootcamp                                   ds tech bootcamp
# 1           stat6021          STAT 6021: Linear Models for Data Science
# 2             ds5100               DS 5100 Programming for Data Science
# 3             cs5012           CS 5012: Foundations of Computer Science
# 4             ds6030  DS 6030: Statistical Learning (prev SYS 6018: ...
# 5   ds_biz_analytics  DS 5559: New Course in Data Science: Business ...
# 6             ds5110  DS 5110: Big Data Systems (prev. DS 5559 Big D...
# 7             ds5001                DS 5001: Exploratory Text Analytics
# 8             ds6001                    DS 6001: Practice & Application
# 9             ds6011                                  DS 6011: Capstone
# 10            ds6040                 DS 6040: Bayesian Machine Learning
# 11            ds6002                        DS 6002: Ethics of Big Data
# ...

# %%
assignments_summer = pd.read_excel('current_learning_objectives_raw_data.xlsx', sheet_name='summer2021_assignments')
assignments_summer['term_id'] = 'summer2021'
assignments_summer
# Out:
#             mnemonic                                        course_name  \
# 0   ds_tech_bootcamp                                   ds tech bootcamp
# 1           stat6021          STAT 6021: Linear Models for Data Science
# 2             ds5100               DS 5100 Programming for Data Science
# 3             cs5012           CS 5012: Foundations of Computer Science
# 4             ds6030  DS 6030: Statistical Learning (prev SYS 6018: ...
# 5             ds5110  DS 5110: Big Data Systems (prev. DS 5559 Big D...
# 6             ds5001                DS 5001: Exploratory Text Analytics
# 7             ds6001                    DS 6001: Practice & Application
# 8             ds6011                                  DS 6011: Capstone
# 9             ds6040                 DS 6040: Bayesian Machine Learning
# 10            ds6002                        DS 6002: Ethics of Big Data
# 11            ds6050                             DS 6050: Deep Learning
# ...

# %%
assignments_spring = pd.read_excel('current_learning_objectives_raw_data.xlsx', sheet_name='spring2021_assignments')
assignments_spring['term_id'] = 'spring2021'
assignments_spring
# Out:
#             mnemonic                                        course_name  \
# 0   ds_tech_bootcamp                                   ds tech bootcamp
# 1           stat6021          STAT 6021: Linear Models for Data Science
# 2             ds5100               DS 5100 Programming for Data Science
# 3             cs5012           CS 5012: Foundations of Computer Science
# 4             ds6030  DS 6030: Statistical Learning (prev SYS 6018: ...
# 5             ds5110  DS 5110: Big Data Systems (prev. DS 5559 Big D...
# 6             ds5001                DS 5001: Exploratory Text Analytics
# 7             ds6001                    DS 6001: Practice & Application
# 8             ds6011                                  DS 6011: Capstone
# 9             ds6040                 DS 6040: Bayesian Machine Learning
# 10            ds6002                      DS 6002: Ethics of Big Data 1
# 11            ds6050                             DS 6050: Deep Learning
# ...

# %% [markdown]
# ## Import Courses

# %%
courses = pd.read_excel('current_learning_objectives_raw_data.xlsx', sheet_name='other_data_raw', skiprows=3, nrows=18 )
courses
# Out:
#             mnemonic                                             name  \
# 0    ds_biz_anaytics           Business Analytics for Data Scientists
# 1   ds_tech_bootcamp                               Technical Bootcamp
# 2             ds5001                       Exploratory Text Analytics
# 3             ds5012                  Foundations of Computer Science
# 4             ds5100                     Programming for Data Science
# 5             ds5110                                 Big Data Systems
# 6             ds6001         Practice and Application of Data Science
# 7             ds6002                                  Big Data Ethics
# 8             ds6011             Data Science Capstone Project Work I
# 9             ds6013            Data Science Capstone Project Work II
# 10            ds6030                             Statistical Learning
# 11            ds6040                        Bayesian Machine Learning
# ...

# %% [markdown]
# ## Import Terms

# %%
terms = pd.read_excel('current_learning_objectives_raw_data.xlsx', sheet_name='other_data_raw', skiprows=24, nrows=4 )
terms
# Out:
#       term_id    term  year  current
# 0  spring2021  spring  2021    False
# 1  summer2021  summer  2021    False
# 2    fall2021    fall  2021     True

# %% [markdown]
# ## Import Instructors

# %%
instructors = pd.read_excel('current_learning_objectives_raw_data.xlsx', sheet_name='other_data_raw', skiprows=30, nrows=26 )
instructors = instructors.iloc[:, :-2]
instructors
# Out:
#                instructor_name  active
# 0                  Pete Alonzi    True
# 1                  Jeffrey Woo    True
# 2                     Judy Fox    True
# 3                Jeremy Bolton   False
# 4                 Bill Basener    True
# 5                Marc Ruggiano    True
# 6                 Adam Tashman    True
# 7             Sree Mallikarjun    True
# 8                 Eric Tassone    True
# 9                 Peter Gedeck    True
# 10            Abbas Kazemipour    True
# 11              Cait Dreisbach    True
# 12                     Lei Xie    True
# 13              Renee Cummings    True
# 14                Stephen Baek    True
# 15                Raf Alvarado    True
# 16                Teague Henry    True
# 17                 Rich Nguyen    True
# 18                  Jon Kropko    True
# 19                  Nada Basit    True
# 20     Panagiotis Apostolellis    True
# 21                 Mike Porter    True
# 22  Luis Felipe Rosado Murillo   False
# ...

# %% [markdown]
# ## Import Learning Objectives

# %%
LO_tech_bootcamp = pd.read_excel('current_learning_objectives_raw_data.xlsx', sheet_name='tech_bootcamp', skiprows=1 )
LO_tech_bootcamp
# Out:
#             MNEMONIC                                   LEARNING OUTCOME
# 0   ds_tech_bootcamp  Research documentation on your own as a first ...
# 1   ds_tech_bootcamp              Describe the components of a computer
# 2   ds_tech_bootcamp  Explain the scales of computational power and ...
# 3   ds_tech_bootcamp  Differentiate between Windows, MacOS ,and Linu...
# 4   ds_tech_bootcamp  Compare Command Line (CLI) and Graphical User ...
# 5   ds_tech_bootcamp   Demonstrate installing software to your computer
# 6   ds_tech_bootcamp               Implement important tasks with Linux
# 7   ds_tech_bootcamp  Create a GitHub account for career or personal...
# 8   ds_tech_bootcamp  Use CLI to operate Git software for version co...
# 9   ds_tech_bootcamp  Use GUI to operate Github website interface fo...
# 10  ds_tech_bootcamp                              Know how to Install R
# 11  ds_tech_bootcamp             Know how to install and launch Rstudio
# ...

# %%
LO_5001 = pd.read_excel('current_learning_objectives_raw_data.xlsx', sheet_name='5001', skiprows=2 )
LO_5001
# Out:
#   MNEMONIC                                   LEARNING OUTCOME
# 0   ds5001  Understand and use language models such as bag...
# 1   ds5001             Understand and use vector space models
# 2   ds5001  Understand how to measure similarity between d...
# 3   ds5001  Understand how Principal Component Analysis (P...
# 4   ds5001  Understand and use topic models such as Latent...
# 5   ds5001  Understand and use word embedding such as glov...
# 6   ds5001  Understand and use sentiment analysis such as ...
# 7   ds5001      Understand and use Naive Bayes classification

# %%
LO_5012 = pd.read_excel('current_learning_objectives_raw_data.xlsx', sheet_name='5012', skiprows=2 )
LO_5100 = pd.read_excel('current_learning_objectives_raw_data.xlsx', sheet_name='5100', skiprows=2 )
LO_5110 = pd.read_excel('current_learning_objectives_raw_data.xlsx', sheet_name='5110', skiprows=2 )
LO_6001 = pd.read_excel('current_learning_objectives_raw_data.xlsx', sheet_name='6001', skiprows=2 )
LO_6002 = pd.read_excel('current_learning_objectives_raw_data.xlsx', sheet_name='6002', skiprows=2 )
LO_6003 = pd.read_excel('current_learning_objectives_raw_data.xlsx', sheet_name='6003', skiprows=2 )
LO_6011 = pd.read_excel('current_learning_objectives_raw_data.xlsx', sheet_name='6011', skiprows=2 )
LO_6012 = pd.read_excel('current_learning_objectives_raw_data.xlsx', sheet_name='6012', skiprows=2 )
LO_6013 = pd.read_excel('current_learning_objectives_raw_data.xlsx', sheet_name='6013', skiprows=2 )
LO_6021 = pd.read_excel('current_learning_objectives_raw_data.xlsx', sheet_name='6021', skiprows=2 )
LO_6030 = pd.read_excel('current_learning_objectives_raw_data.xlsx', sheet_name='6030', skiprows=2 )
LO_6050 = pd.read_excel('current_learning_objectives_raw_data.xlsx', sheet_name='6050', skiprows=2 )
LO_6030
# Out:
#    MNEMONIC                                   LEARNING OUTCOME
# 0    ds6030  Build classification and regression models for...
# 1    ds6030  Explain the statistical theory used in data mi...
# 2    ds6030  For a given data set and model, determine the ...
# 3    ds6030  Evaluate the performance of a model in terms o...
# 4    ds6030  Determine the most appropriate algorithm for a...
# 5    ds6030  Use visualization techniques to help users und...
# 6    ds6030  Implement KNN regression and classification mo...
# 7    ds6030  Build linear and nonlinear regression models in R
# 8    ds6030  Evaluate bias-variance tradeoff of linear regr...
# 9    ds6030     Implement LR, LDA, and QDA classification in R
# 10   ds6030                         Implement cross-validation
# 11   ds6030  Understand the theory behind principal components
# 12   ds6030  Use principal components transformation to vis...
# 13   ds6030  Use regularization (shrinkage, PCA, lasso) to ...
# ...

# %%
LO_6040 = pd.read_excel('current_learning_objectives_raw_data.xlsx', sheet_name='6040', skiprows=3 )
LO_6040
# Out:
#    MNEMONIC                                   LEARNING OUTCOME
# 0    ds6040                                 Probability review
# 1    ds6040  Use the elements of Bayes theorem in problem s...
# 2    ds6040  Use univariate conjugate priors to analyticall...
# 3    ds6040  Use multivariate conjugate priors to analytica...
# 4    ds6040  Use non-informative priors to analytically obt...
# 5    ds6040  Formulate real problems using the fundamentals...
# 6    ds6040  Apply the principles of statistical decision t...
# 7    ds6040  Develop approximate solutions when the require...
# 8    ds6040  Apply the principles of statistical decision t...
# 9    ds6040  Formulate a graphical representation of a join...
# 10   ds6040               Display Bayesian models using graphs
# 11   ds6040           Represent generative models using graphs
# 12   ds6040  Apply graphical methods to real problems in te...
# 13   ds6040  Apply simple sampling methods to approximate d...
# ...

# %%
LO_biz_analytics = pd.read_excel('current_learning_objectives_raw_data.xlsx', sheet_name='biz_analytics', skiprows=2 )
LO_biz_analytics
# Out:
#            MNEMONIC                                   LEARNING OUTCOME
# 0  ds_biz_analytics  Understand the fundamentals of modern business...
# 1  ds_biz_analytics  Apply data science tools to the primary busine...
# 2  ds_biz_analytics  Understand key data sources, models, metrics, ...
# 3  ds_biz_analytics  Apply ethical data science principles to key b...
# 4  ds_biz_analytics  Use critical thinking skills to understand, an...
# 5  ds_biz_analytics  Communicate effectively in both speech and wri...
# 6  ds_biz_analytics                 Collaborate effectively with peers
# 7  ds_biz_analytics             Formulate and ask insightful questions
# 8  ds_biz_analytics  Engage appropriately with senior executives at...

# %% [markdown]
# ## Write tables to CSVs

# %%
assignments_fall.to_csv('assignments_fall_csv.csv', index=False)
assignments_summer.to_csv('assignments_summer_csv.csv', index=False)
assignments_spring.to_csv('assignments_spring_csv.csv', index=False)

# %%
courses.to_csv('courses_csv.csv', index=False)
terms.to_csv('terms_csv.csv', index=False)
instructors.to_csv('instructors_csv.csv', index=False)

# %%
LO_tech_bootcamp.to_csv('tech_bootcamp_csv.csv', index=False)
LO_biz_analytics.to_csv('tech_biz_analytics_csv.csv', index=False)
LO_5001.to_csv('5001_csv.csv', index=False)
LO_5012.to_csv('5012_csv.csv', index=False)
LO_5100.to_csv('5100_csv.csv', index=False)
LO_5110.to_csv('5110_csv.csv', index=False)
LO_6001.to_csv('6001_csv.csv', index=False)
LO_6002.to_csv('6002_csv.csv', index=False)
LO_6003.to_csv('6003_csv.csv', index=False)
LO_6011.to_csv('6011_csv.csv', index=False)
LO_6012.to_csv('6012_csv.csv', index=False)
LO_6013.to_csv('6013_csv.csv', index=False)
LO_6021.to_csv('6021_csv.csv', index=False)
LO_6030.to_csv('6030_csv.csv', index=False)
LO_6050.to_csv('6050_csv.csv', index=False)
LO_6040.to_csv('6040_csv.csv', index=False)

# %% [markdown]
# ## Create and Export larger LO and Assignment table

# %%
learning_objectives = pd.concat([LO_tech_bootcamp,LO_biz_analytics,LO_5001, LO_5012, LO_5100, LO_5110, LO_6001, LO_6002, LO_6003, LO_6011, LO_6012, LO_6013, LO_6021, LO_6030, LO_6040, LO_6050], ignore_index=True)
learning_objectives
# Out:
#              MNEMONIC                                   LEARNING OUTCOME
# 0    ds_tech_bootcamp  Research documentation on your own as a first ...
# 1    ds_tech_bootcamp              Describe the components of a computer
# 2    ds_tech_bootcamp  Explain the scales of computational power and ...
# 3    ds_tech_bootcamp  Differentiate between Windows, MacOS ,and Linu...
# 4    ds_tech_bootcamp  Compare Command Line (CLI) and Graphical User ...
# ..                ...                                                ...
# 225            ds6050  Understand how to deploy models to TF Serving ...
# 226            ds6050  Deploy models to mobile apps, embedded devices...
# 227            ds6050            Understand how adversarial attacks work
# 228            ds6050                Explore bias in data and algorithms
# 229            ds6050       Analyze the issues in uncertainty estimation
#
# [230 rows x 2 columns]

# %%
learning_objectives.to_csv('learning_objectives_csv.csv', index=False)

# %%
assignments = pd.concat([assignments_fall,assignments_summer,assignments_spring], ignore_index=True)

assignments['instructor_assignments'] = assignments['instructor_assignments'].astype('string')
assignments['instructor_assignments'] = assignments['instructor_assignments'].str.split(',| & ').apply(lambda x: [item.strip() for item in x]) # Need to make the intructor assignments atomic (split names into separate rows)
assignments = assignments.explode('instructor_assignments').reset_index(drop=True)
assignments
# Out:
#             mnemonic                                        course_name  \
# 0   ds_tech_bootcamp                                   ds tech bootcamp
# 1           stat6021          STAT 6021: Linear Models for Data Science
# 2             ds5100               DS 5100 Programming for Data Science
# 3             cs5012           CS 5012: Foundations of Computer Science
# 4             ds6030  DS 6030: Statistical Learning (prev SYS 6018: ...
# 5   ds_biz_analytics  DS 5559: New Course in Data Science: Business ...
# 6             ds5110  DS 5110: Big Data Systems (prev. DS 5559 Big D...
# 7             ds5001                DS 5001: Exploratory Text Analytics
# 8             ds6001                    DS 6001: Practice & Application
# 9             ds6011                                  DS 6011: Capstone
# 10            ds6011                                  DS 6011: Capstone
# 11            ds6011                                  DS 6011: Capstone
# ...

# %%
assignments.to_csv('assignments_csv.csv', index=False)
